# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 18s 10ms/step - loss: 0.0055 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00194, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 15s 9ms/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00194 to 0.00192, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 15s 9ms/step - loss: 0.0013 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00192 to 0.00181, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 15s 9ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00181
# Epoch 5/150
# 1712/1712 [==============================] - 15s 9ms/step - loss: 0.0010 - val_loss: 0.0017
#
# Epoch 00005: val_loss improved from 0.00181 to 0.00175, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 15s 9ms/step - loss: 9.4951e-04 - val_loss: 0.0016
#
# Epoch 00006: val_loss improved from 0.00175 to 0.00162, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 16s 9ms/step - loss: 7.6161e-04 - val_loss: 0.0015
#
# Epoch 00007: val_loss improved from 0.00162 to 0.00148, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 15s 9ms/step - loss: 6.6246e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00148 to 0.00137, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 16s 9ms/step - loss: 6.0680e-04 - val_loss: 0.0012
#
# Epoch 00009: val_loss improved from 0.00137 to 0.00120, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 16s 9ms/step - loss: 5.5277e-04 - val_loss: 0.0011
#
# Epoch 00010: val_loss improved from 0.00120 to 0.00114, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 16s 9ms/step - loss: 5.1176e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00114 to 0.00108, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 4.7397e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss did not improve from 0.00108
# Epoch 13/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 4.4961e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00108 to 0.00106, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 4.1566e-04 - val_loss: 9.9146e-04
#
# Epoch 00014: val_loss improved from 0.00106 to 0.00099, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 4.0421e-04 - val_loss: 9.6280e-04
#
# Epoch 00015: val_loss improved from 0.00099 to 0.00096, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 3.8501e-04 - val_loss: 9.1449e-04
#
# Epoch 00016: val_loss improved from 0.00096 to 0.00091, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 16s 10ms/step - loss: 3.5947e-04 - val_loss: 8.6628e-04
#
# Epoch 00017: val_loss improved from 0.00091 to 0.00087, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 16s 9ms/step - loss: 3.5225e-04 - val_loss: 9.1456e-04
#
# Epoch 00018: val_loss did not improve from 0.00087
# Epoch 19/150
# 1712/1712 [==============================] - 16s 10ms/step - loss: 3.4673e-04 - val_loss: 8.6103e-04
#
# Epoch 00019: val_loss improved from 0.00087 to 0.00086, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 18s 10ms/step - loss: 3.1811e-04 - val_loss: 9.1016e-04
#
# Epoch 00020: val_loss did not improve from 0.00086
# Epoch 21/150
# 1712/1712 [==============================] - 16s 9ms/step - loss: 3.1431e-04 - val_loss: 8.5030e-04
#
# Epoch 00021: val_loss improved from 0.00086 to 0.00085, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 16s 10ms/step - loss: 3.0747e-04 - val_loss: 8.5384e-04
#
# Epoch 00022: val_loss did not improve from 0.00085
# Epoch 23/150
# 1712/1712 [==============================] - 16s 9ms/step - loss: 2.9243e-04 - val_loss: 8.5895e-04
#
# Epoch 00023: val_loss did not improve from 0.00085
# Epoch 24/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 2.9315e-04 - val_loss: 8.6350e-04
#
# Epoch 00024: val_loss did not improve from 0.00085
# Epoch 25/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 2.7971e-04 - val_loss: 8.2603e-04
#
# Epoch 00025: val_loss improved from 0.00085 to 0.00083, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 2.7688e-04 - val_loss: 8.1170e-04
#
# Epoch 00026: val_loss improved from 0.00083 to 0.00081, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.6762e-04 - val_loss: 8.3384e-04
#
# Epoch 00027: val_loss did not improve from 0.00081
# Epoch 28/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 2.6526e-04 - val_loss: 8.2800e-04
#
# Epoch 00028: val_loss did not improve from 0.00081
# Epoch 29/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.5347e-04 - val_loss: 8.9429e-04
#
# Epoch 00029: val_loss did not improve from 0.00081
# Epoch 30/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.5290e-04 - val_loss: 7.9272e-04
#
# Epoch 00030: val_loss improved from 0.00081 to 0.00079, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 2.4933e-04 - val_loss: 7.8969e-04
#
# Epoch 00031: val_loss improved from 0.00079 to 0.00079, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 2.4445e-04 - val_loss: 8.1557e-04
#
# Epoch 00032: val_loss did not improve from 0.00079
# Epoch 33/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 2.3294e-04 - val_loss: 7.9296e-04
#
# Epoch 00033: val_loss did not improve from 0.00079
# Epoch 34/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 2.3803e-04 - val_loss: 7.9302e-04
#
# Epoch 00034: val_loss did not improve from 0.00079
# Epoch 35/150
# 1712/1712 [==============================] - 20s 12ms/step - loss: 2.1969e-04 - val_loss: 7.8463e-04
#
# Epoch 00035: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 23s 13ms/step - loss: 2.1542e-04 - val_loss: 7.7925e-04
#
# Epoch 00036: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 2.1780e-04 - val_loss: 7.7706e-04
#
# Epoch 00037: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 2.2055e-04 - val_loss: 7.7028e-04
#
# Epoch 00038: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 39/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 2.1061e-04 - val_loss: 7.5532e-04
#
# Epoch 00039: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 23s 14ms/step - loss: 2.0337e-04 - val_loss: 7.6857e-04
#
# Epoch 00040: val_loss did not improve from 0.00076
# Epoch 41/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 2.0274e-04 - val_loss: 7.6571e-04
#
# Epoch 00041: val_loss did not improve from 0.00076
# Epoch 42/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 2.0124e-04 - val_loss: 7.5797e-04
#
# Epoch 00042: val_loss did not improve from 0.00076
# Epoch 43/150
# 1712/1712 [==============================] - 22s 13ms/step - loss: 1.9675e-04 - val_loss: 7.5536e-04
#
# Epoch 00043: val_loss did not improve from 0.00076
# Epoch 44/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.9456e-04 - val_loss: 7.5235e-04
#
# Epoch 00044: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 45/150
# 1712/1712 [==============================] - 23s 13ms/step - loss: 1.8742e-04 - val_loss: 7.2947e-04
#
# Epoch 00045: val_loss improved from 0.00075 to 0.00073, saving model to best_weights.h5
# Epoch 46/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.9217e-04 - val_loss: 7.8228e-04
#
# Epoch 00046: val_loss did not improve from 0.00073
# Epoch 47/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.8344e-04 - val_loss: 7.3408e-04
#
# Epoch 00047: val_loss did not improve from 0.00073
# Epoch 48/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.8052e-04 - val_loss: 7.6735e-04
#
# Epoch 00048: val_loss did not improve from 0.00073
# Epoch 49/150
# 1712/1712 [==============================] - 22s 13ms/step - loss: 1.7581e-04 - val_loss: 7.4906e-04
#
# Epoch 00049: val_loss did not improve from 0.00073
# Epoch 50/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.7687e-04 - val_loss: 7.4406e-04
#
# Epoch 00050: val_loss did not improve from 0.00073
# Epoch 51/150
# 1712/1712 [==============================] - 23s 13ms/step - loss: 1.7116e-04 - val_loss: 7.4632e-04
#
# Epoch 00051: val_loss did not improve from 0.00073
# Epoch 52/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.7545e-04 - val_loss: 7.9478e-04
#
# Epoch 00052: val_loss did not improve from 0.00073
# Epoch 53/150
# 1712/1712 [==============================] - 20s 12ms/step - loss: 1.7458e-04 - val_loss: 7.3634e-04
#
# Epoch 00053: val_loss did not improve from 0.00073
# Epoch 54/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.8639e-04 - val_loss: 7.3222e-04
#
# Epoch 00054: val_loss did not improve from 0.00073
# Epoch 55/150
# 1712/1712 [==============================] - 22s 13ms/step - loss: 1.7467e-04 - val_loss: 7.3954e-04
#
# Epoch 00055: val_loss did not improve from 0.00073
# Epoch 56/150
# 1712/1712 [==============================] - 20s 12ms/step - loss: 1.6402e-04 - val_loss: 7.4180e-04
#
# Epoch 00056: val_loss did not improve from 0.00073
# Epoch 57/150
# 1712/1712 [==============================] - 22s 13ms/step - loss: 1.6635e-04 - val_loss: 7.6494e-04
#
# Epoch 00057: val_loss did not improve from 0.00073
# Epoch 58/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.6412e-04 - val_loss: 7.3883e-04
#
# Epoch 00058: val_loss did not improve from 0.00073
# Epoch 59/150
# 1712/1712 [==============================] - 22s 13ms/step - loss: 1.6666e-04 - val_loss: 7.2808e-04
#
# Epoch 00059: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 60/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.6561e-04 - val_loss: 7.5404e-04
#
# Epoch 00060: val_loss did not improve from 0.00073
# Epoch 61/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.5888e-04 - val_loss: 7.6161e-04
#
# Epoch 00061: val_loss did not improve from 0.00073
# Epoch 62/150
# 1712/1712 [==============================] - 22s 13ms/step - loss: 1.5725e-04 - val_loss: 7.1449e-04
#
# Epoch 00062: val_loss improved from 0.00073 to 0.00071, saving model to best_weights.h5
# Epoch 63/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.5535e-04 - val_loss: 7.5989e-04
#
# Epoch 00063: val_loss did not improve from 0.00071
# Epoch 64/150
# 1712/1712 [==============================] - 22s 13ms/step - loss: 1.5059e-04 - val_loss: 7.3653e-04
#
# Epoch 00064: val_loss did not improve from 0.00071
# Epoch 65/150
# 1712/1712 [==============================] - 23s 13ms/step - loss: 1.4964e-04 - val_loss: 7.3971e-04
#
# Epoch 00065: val_loss did not improve from 0.00071
# Epoch 66/150
# 1712/1712 [==============================] - 21s 13ms/step - loss: 1.4647e-04 - val_loss: 7.2658e-04
#
# Epoch 00066: val_loss did not improve from 0.00071
# Epoch 67/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.4533e-04 - val_loss: 7.1772e-04
#
# Epoch 00067: val_loss did not improve from 0.00071
# Epoch 68/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.4031e-04 - val_loss: 7.3168e-04
#
# Epoch 00068: val_loss did not improve from 0.00071
# Epoch 69/150
# 1712/1712 [==============================] - 23s 13ms/step - loss: 1.4527e-04 - val_loss: 7.3219e-04
#
# Epoch 00069: val_loss did not improve from 0.00071
# Epoch 70/150
# 1712/1712 [==============================] - 22s 13ms/step - loss: 1.4509e-04 - val_loss: 7.5188e-04
#
# Epoch 00070: val_loss did not improve from 0.00071
# Epoch 71/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.4196e-04 - val_loss: 7.4834e-04
#
# Epoch 00071: val_loss did not improve from 0.00071
# Epoch 72/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.3897e-04 - val_loss: 7.5617e-04
#
# Epoch 00072: val_loss did not improve from 0.00071
# Epoch 73/150
# 1712/1712 [==============================] - 23s 13ms/step - loss: 1.4096e-04 - val_loss: 7.1633e-04
#
# Epoch 00073: val_loss did not improve from 0.00071
# Epoch 74/150
# 1712/1712 [==============================] - 20s 12ms/step - loss: 1.3960e-04 - val_loss: 7.4115e-04
#
# Epoch 00074: val_loss did not improve from 0.00071
# Epoch 75/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.4024e-04 - val_loss: 7.3393e-04
#
# Epoch 00075: val_loss did not improve from 0.00071
# Epoch 76/150
# 1712/1712 [==============================] - 22s 13ms/step - loss: 1.3936e-04 - val_loss: 7.1285e-04
#
# Epoch 00076: val_loss improved from 0.00071 to 0.00071, saving model to best_weights.h5
# Epoch 77/150
# 1712/1712 [==============================] - 20s 12ms/step - loss: 1.3914e-04 - val_loss: 7.3049e-04
#
# Epoch 00077: val_loss did not improve from 0.00071
# Epoch 78/150
# 1712/1712 [==============================] - 22s 13ms/step - loss: 1.3560e-04 - val_loss: 7.5562e-04
#
# Epoch 00078: val_loss did not improve from 0.00071
# Epoch 79/150
# 1712/1712 [==============================] - 27s 16ms/step - loss: 1.3198e-04 - val_loss: 7.4626e-04
#
# Epoch 00079: val_loss did not improve from 0.00071
# Epoch 80/150
# 1712/1712 [==============================] - 22s 13ms/step - loss: 1.2755e-04 - val_loss: 7.5843e-04
#
# Epoch 00080: val_loss did not improve from 0.00071
# Epoch 81/150
# 1712/1712 [==============================] - 20s 11ms/step - loss: 1.3039e-04 - val_loss: 7.2605e-04
#
# Epoch 00081: val_loss did not improve from 0.00071
# Epoch 82/150
# 1712/1712 [==============================] - 20s 12ms/step - loss: 1.2689e-04 - val_loss: 7.4810e-04
#
# Epoch 00082: val_loss did not improve from 0.00071
# Epoch 83/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.2714e-04 - val_loss: 7.6667e-04
#
# Epoch 00083: val_loss did not improve from 0.00071
# Epoch 84/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.2871e-04 - val_loss: 7.4594e-04
#
# Epoch 00084: val_loss did not improve from 0.00071
# Epoch 85/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 1.2564e-04 - val_loss: 7.2029e-04
#
# Epoch 00085: val_loss did not improve from 0.00071
# Epoch 86/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.2887e-04 - val_loss: 7.0505e-04
#
# Epoch 00086: val_loss improved from 0.00071 to 0.00071, saving model to best_weights.h5
# Epoch 87/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 1.2457e-04 - val_loss: 7.6048e-04
#
# Epoch 00087: val_loss did not improve from 0.00071
# Epoch 88/150
# 1712/1712 [==============================] - 20s 12ms/step - loss: 1.2404e-04 - val_loss: 7.9625e-04
#
# Epoch 00088: val_loss did not improve from 0.00071
# Epoch 89/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.2291e-04 - val_loss: 7.5486e-04
#
# Epoch 00089: val_loss did not improve from 0.00071
# Epoch 90/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.2144e-04 - val_loss: 7.3060e-04
#
# Epoch 00090: val_loss did not improve from 0.00071
# Epoch 91/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.1821e-04 - val_loss: 7.2652e-04
#
# Epoch 00091: val_loss did not improve from 0.00071
# Epoch 92/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.1833e-04 - val_loss: 7.1683e-04
#
# Epoch 00092: val_loss did not improve from 0.00071
# Epoch 93/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.2001e-04 - val_loss: 7.2247e-04
#
# Epoch 00093: val_loss did not improve from 0.00071
# Epoch 94/150
# 1712/1712 [==============================] - 22s 13ms/step - loss: 1.1624e-04 - val_loss: 7.3625e-04
#
# Epoch 00094: val_loss did not improve from 0.00071
# Epoch 95/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.1659e-04 - val_loss: 7.6470e-04
#
# Epoch 00095: val_loss did not improve from 0.00071
# Epoch 96/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.1237e-04 - val_loss: 7.3856e-04
#
# Epoch 00096: val_loss did not improve from 0.00071
# Epoch 97/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 1.1217e-04 - val_loss: 7.5378e-04
#
# Epoch 00097: val_loss did not improve from 0.00071
# Epoch 98/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 1.1068e-04 - val_loss: 7.3483e-04
#
# Epoch 00098: val_loss did not improve from 0.00071
# Epoch 99/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.1299e-04 - val_loss: 7.5214e-04
#
# Epoch 00099: val_loss did not improve from 0.00071
# Epoch 100/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.0654e-04 - val_loss: 7.3881e-04
#
# Epoch 00100: val_loss did not improve from 0.00071
# Epoch 101/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 1.0756e-04 - val_loss: 7.3065e-04
#
# Epoch 00101: val_loss did not improve from 0.00071
# Epoch 102/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.0697e-04 - val_loss: 7.4127e-04
#
# Epoch 00102: val_loss did not improve from 0.00071
# Epoch 103/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 1.1069e-04 - val_loss: 7.4796e-04
#
# Epoch 00103: val_loss did not improve from 0.00071
# Epoch 104/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.0958e-04 - val_loss: 7.6259e-04
#
# Epoch 00104: val_loss did not improve from 0.00071
# Epoch 105/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.0912e-04 - val_loss: 7.5595e-04
#
# Epoch 00105: val_loss did not improve from 0.00071
# Epoch 106/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 1.0610e-04 - val_loss: 7.2310e-04
#
# Epoch 00106: val_loss did not improve from 0.00071
# Epoch 107/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.0428e-04 - val_loss: 7.2822e-04
#
# Epoch 00107: val_loss did not improve from 0.00071
# Epoch 108/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 1.0264e-04 - val_loss: 7.4995e-04
#
# Epoch 00108: val_loss did not improve from 0.00071
# Epoch 109/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.0533e-04 - val_loss: 7.5864e-04
#
# Epoch 00109: val_loss did not improve from 0.00071
# Epoch 110/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.0342e-04 - val_loss: 7.5893e-04
#
# Epoch 00110: val_loss did not improve from 0.00071
# Epoch 111/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.0382e-04 - val_loss: 7.5606e-04
#
# Epoch 00111: val_loss did not improve from 0.00071
# Epoch 112/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 9.9166e-05 - val_loss: 7.4102e-04
#
# Epoch 00112: val_loss did not improve from 0.00071
# Epoch 113/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 9.9732e-05 - val_loss: 7.3186e-04
#
# Epoch 00113: val_loss did not improve from 0.00071
# Epoch 114/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 1.0236e-04 - val_loss: 7.3079e-04
#
# Epoch 00114: val_loss did not improve from 0.00071
# Epoch 115/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 1.0211e-04 - val_loss: 7.3662e-04
#
# Epoch 00115: val_loss did not improve from 0.00071
# Epoch 116/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 1.0037e-04 - val_loss: 7.2702e-04
#
# Epoch 00116: val_loss did not improve from 0.00071
# Epoch 117/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 9.7307e-05 - val_loss: 7.4567e-04
#
# Epoch 00117: val_loss did not improve from 0.00071
# Epoch 118/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 9.8956e-05 - val_loss: 7.3484e-04
#
# Epoch 00118: val_loss did not improve from 0.00071
# Epoch 119/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 1.0307e-04 - val_loss: 7.4185e-04
#
# Epoch 00119: val_loss did not improve from 0.00071
# Epoch 120/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 9.8601e-05 - val_loss: 7.6361e-04
#
# Epoch 00120: val_loss did not improve from 0.00071
# Epoch 121/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 9.5763e-05 - val_loss: 7.6137e-04
#
# Epoch 00121: val_loss did not improve from 0.00071
# Epoch 122/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 9.6341e-05 - val_loss: 7.2715e-04
#
# Epoch 00122: val_loss did not improve from 0.00071
# Epoch 123/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 9.7624e-05 - val_loss: 7.1995e-04
#
# Epoch 00123: val_loss did not improve from 0.00071
# Epoch 124/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 9.5284e-05 - val_loss: 7.2590e-04
#
# Epoch 00124: val_loss did not improve from 0.00071
# Epoch 125/150
# 1712/1712 [==============================] - 20s 12ms/step - loss: 9.3988e-05 - val_loss: 7.6857e-04
#
# Epoch 00125: val_loss did not improve from 0.00071
# Epoch 126/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 9.4936e-05 - val_loss: 7.1645e-04
#
# Epoch 00126: val_loss did not improve from 0.00071
# Epoch 127/150
# 1712/1712 [==============================] - 18s 10ms/step - loss: 9.2850e-05 - val_loss: 7.1677e-04
#
# Epoch 00127: val_loss did not improve from 0.00071
# Epoch 128/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 9.3391e-05 - val_loss: 7.1739e-04
#
# Epoch 00128: val_loss did not improve from 0.00071
# Epoch 129/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 9.9114e-05 - val_loss: 7.4505e-04
#
# Epoch 00129: val_loss did not improve from 0.00071
# Epoch 130/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 9.8505e-05 - val_loss: 7.6278e-04
#
# Epoch 00130: val_loss did not improve from 0.00071
# Epoch 131/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 9.5007e-05 - val_loss: 7.7644e-04
#
# Epoch 00131: val_loss did not improve from 0.00071
# Epoch 132/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 9.3885e-05 - val_loss: 7.5696e-04
#
# Epoch 00132: val_loss did not improve from 0.00071
# Epoch 133/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 9.1785e-05 - val_loss: 7.4910e-04
#
# Epoch 00133: val_loss did not improve from 0.00071
# Epoch 134/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 8.9774e-05 - val_loss: 7.3690e-04
#
# Epoch 00134: val_loss did not improve from 0.00071
# Epoch 135/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 9.0178e-05 - val_loss: 7.2625e-04
#
# Epoch 00135: val_loss did not improve from 0.00071
# Epoch 136/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 8.7917e-05 - val_loss: 7.3744e-04
#
# Epoch 00136: val_loss did not improve from 0.00071
# Epoch 137/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 8.9268e-05 - val_loss: 7.4629e-04
#
# Epoch 00137: val_loss did not improve from 0.00071
# Epoch 138/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 9.1088e-05 - val_loss: 7.2551e-04
#
# Epoch 00138: val_loss did not improve from 0.00071
# Epoch 139/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 8.5792e-05 - val_loss: 7.3192e-04
#
# Epoch 00139: val_loss did not improve from 0.00071
# Epoch 140/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 8.6530e-05 - val_loss: 7.2665e-04
#
# Epoch 00140: val_loss did not improve from 0.00071
# Epoch 141/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 8.6452e-05 - val_loss: 7.4373e-04
#
# Epoch 00141: val_loss did not improve from 0.00071
# Epoch 142/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 8.7033e-05 - val_loss: 7.2103e-04
#
# Epoch 00142: val_loss did not improve from 0.00071
# Epoch 143/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 8.9891e-05 - val_loss: 7.4598e-04
#
# Epoch 00143: val_loss did not improve from 0.00071
# Epoch 144/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 8.4808e-05 - val_loss: 7.2451e-04
#
# Epoch 00144: val_loss did not improve from 0.00071
# Epoch 145/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 8.6015e-05 - val_loss: 7.1825e-04
#
# Epoch 00145: val_loss did not improve from 0.00071
# Epoch 146/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 8.4657e-05 - val_loss: 7.5185e-04
#
# Epoch 00146: val_loss did not improve from 0.00071
# Epoch 147/150
# 1712/1712 [==============================] - 19s 11ms/step - loss: 8.2160e-05 - val_loss: 7.4074e-04
#
# Epoch 00147: val_loss did not improve from 0.00071
# Epoch 148/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 8.3517e-05 - val_loss: 7.5482e-04
#
# Epoch 00148: val_loss did not improve from 0.00071
# Epoch 149/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 8.1625e-05 - val_loss: 7.5364e-04
#
# Epoch 00149: val_loss did not improve from 0.00071
# Epoch 150/150
# 1712/1712 [==============================] - 18s 11ms/step - loss: 8.5593e-05 - val_loss: 7.2995e-04
#
# Epoch 00150: val_loss did not improve from 0.00071

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
def augment_image_and_point(img, point):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # flip image
    for i in range(rows):
        for j in range(cols // 2):
            new_img[i][j] , new_img[i][cols-j-1] = img[i][cols-j-1], img[i][j]
            
    # flip key point -0.5->0.5, 0.5->-0.5
    new_point = np.copy(point)
    for i in range(0,len(point),2):
        new_point[i] = -point[i]
    
    # revert right and left in label
    new_point_temp = np.copy(new_point)
    # eye_center
    new_point[0:2] = new_point_temp[2:4]
    new_point[2:4] = new_point_temp[0:2]
    # eye_inner_corner
    new_point[4:6] = new_point_temp[8:10]
    new_point[8:10] = new_point_temp[4:6]
    # eye_outer_corner
    new_point[6:8] = new_point_temp[10:12]
    new_point[10:12] = new_point_temp[6:8]
    # eyebrow_inner_end
    new_point[12:14] = new_point_temp[16:18]
    new_point[16:18] = new_point_temp[12:14]
    # eyebrow_outer_end
    new_point[14:16] = new_point_temp[18:20]
    new_point[18:20] = new_point_temp[14:16]
    # mouth_corner
    new_point[22:24] = new_point_temp[24:26]
    new_point[24:26] = new_point_temp[22:24]
        
    return new_img, new_point

# %%
# create list of augmentation images and points
aug_imgs_train = []
aug_points_train = []

# augmentation
for i in range(imgs_train.shape[0]):
    aug_img, aug_point = augment_image_and_point(imgs_train[i], points_train[i])
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

# append origin images and data
aug_imgs_train = np.append(aug_imgs_train, imgs_train, axis=0)
aug_points_train = np.append(aug_points_train, points_train, axis=0)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
aug_checkpoint = ModelCheckpoint('aug_best_weights.h5', verbose=1, save_best_only=True)
aug_hist = History()

# %%
# training the model
aug_hist_model = model_with_augment.fit(aug_imgs_train.reshape(-1, 96, 96, 1), 
                       aug_points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[aug_checkpoint, aug_hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model_with_augment.save_weights('aug_weights.h5')
# save the model
model_with_augment.save('aug_model.h5')
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 32s 9ms/step - loss: 0.0042 - val_loss: 0.0016
#
# Epoch 00001: val_loss improved from inf to 0.00159, saving model to aug_best_weights.h5
# Epoch 2/150
# 3424/3424 [==============================] - 30s 9ms/step - loss: 0.0014 - val_loss: 0.0015
#
# Epoch 00002: val_loss improved from 0.00159 to 0.00149, saving model to aug_best_weights.h5
# Epoch 3/150
# 3424/3424 [==============================] - 32s 9ms/step - loss: 0.0011 - val_loss: 0.0013
#
# Epoch 00003: val_loss improved from 0.00149 to 0.00128, saving model to aug_best_weights.h5
# Epoch 4/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 8.4885e-04 - val_loss: 9.4136e-04
#
# Epoch 00004: val_loss improved from 0.00128 to 0.00094, saving model to aug_best_weights.h5
# Epoch 5/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 6.8566e-04 - val_loss: 8.3788e-04
#
# Epoch 00005: val_loss improved from 0.00094 to 0.00084, saving model to aug_best_weights.h5
# Epoch 6/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 5.8053e-04 - val_loss: 7.8132e-04
#
# Epoch 00006: val_loss improved from 0.00084 to 0.00078, saving model to aug_best_weights.h5
# Epoch 7/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 5.3538e-04 - val_loss: 6.7533e-04
#
# Epoch 00007: val_loss improved from 0.00078 to 0.00068, saving model to aug_best_weights.h5
# Epoch 8/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 4.7047e-04 - val_loss: 6.2984e-04
#
# Epoch 00008: val_loss improved from 0.00068 to 0.00063, saving model to aug_best_weights.h5
# Epoch 9/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 4.4028e-04 - val_loss: 5.9522e-04
#
# Epoch 00009: val_loss improved from 0.00063 to 0.00060, saving model to aug_best_weights.h5
# Epoch 10/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 4.0949e-04 - val_loss: 6.0082e-04
#
# Epoch 00010: val_loss did not improve from 0.00060
# Epoch 11/150
# 3424/3424 [==============================] - 32s 9ms/step - loss: 3.7860e-04 - val_loss: 5.4419e-04
#
# Epoch 00011: val_loss improved from 0.00060 to 0.00054, saving model to aug_best_weights.h5
# Epoch 12/150
# 3424/3424 [==============================] - 39s 11ms/step - loss: 3.5629e-04 - val_loss: 5.1903e-04
#
# Epoch 00012: val_loss improved from 0.00054 to 0.00052, saving model to aug_best_weights.h5
# Epoch 13/150
# 3424/3424 [==============================] - 37s 11ms/step - loss: 3.5182e-04 - val_loss: 5.7165e-04
#
# Epoch 00013: val_loss did not improve from 0.00052
# Epoch 14/150
# 3424/3424 [==============================] - 36s 10ms/step - loss: 3.3362e-04 - val_loss: 4.9414e-04
#
# Epoch 00014: val_loss improved from 0.00052 to 0.00049, saving model to aug_best_weights.h5
# Epoch 15/150
# 3424/3424 [==============================] - 39s 11ms/step - loss: 3.2254e-04 - val_loss: 4.8826e-04
#
# Epoch 00015: val_loss improved from 0.00049 to 0.00049, saving model to aug_best_weights.h5
# Epoch 16/150
# 3424/3424 [==============================] - 37s 11ms/step - loss: 3.1089e-04 - val_loss: 4.6946e-04
#
# Epoch 00016: val_loss improved from 0.00049 to 0.00047, saving model to aug_best_weights.h5
# Epoch 17/150
# 3424/3424 [==============================] - 35s 10ms/step - loss: 2.8837e-04 - val_loss: 4.6101e-04
#
# Epoch 00017: val_loss improved from 0.00047 to 0.00046, saving model to aug_best_weights.h5
# Epoch 18/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 2.8264e-04 - val_loss: 4.4225e-04
#
# Epoch 00018: val_loss improved from 0.00046 to 0.00044, saving model to aug_best_weights.h5
# Epoch 19/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 2.7177e-04 - val_loss: 4.5557e-04
#
# Epoch 00019: val_loss did not improve from 0.00044
# Epoch 20/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 2.7234e-04 - val_loss: 4.4853e-04
#
# Epoch 00020: val_loss did not improve from 0.00044
# Epoch 21/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 2.5702e-04 - val_loss: 4.4394e-04
#
# Epoch 00021: val_loss did not improve from 0.00044
# Epoch 22/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 2.5028e-04 - val_loss: 4.4266e-04
#
# Epoch 00022: val_loss did not improve from 0.00044
# Epoch 23/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 2.4387e-04 - val_loss: 4.3999e-04
#
# Epoch 00023: val_loss improved from 0.00044 to 0.00044, saving model to aug_best_weights.h5
# Epoch 24/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 2.4886e-04 - val_loss: 4.4275e-04
#
# Epoch 00024: val_loss did not improve from 0.00044
# Epoch 25/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 2.3631e-04 - val_loss: 4.3969e-04
#
# Epoch 00025: val_loss improved from 0.00044 to 0.00044, saving model to aug_best_weights.h5
# Epoch 26/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 2.3300e-04 - val_loss: 4.2313e-04
#
# Epoch 00026: val_loss improved from 0.00044 to 0.00042, saving model to aug_best_weights.h5
# Epoch 27/150
# 3424/3424 [==============================] - 39s 12ms/step - loss: 2.2384e-04 - val_loss: 4.2105e-04
#
# Epoch 00027: val_loss improved from 0.00042 to 0.00042, saving model to aug_best_weights.h5
# Epoch 28/150
# 3424/3424 [==============================] - 36s 11ms/step - loss: 2.1982e-04 - val_loss: 4.2454e-04
#
# Epoch 00028: val_loss did not improve from 0.00042
# Epoch 29/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 2.1783e-04 - val_loss: 4.2634e-04
#
# Epoch 00029: val_loss did not improve from 0.00042
# Epoch 30/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 2.1528e-04 - val_loss: 4.1653e-04
#
# Epoch 00030: val_loss improved from 0.00042 to 0.00042, saving model to aug_best_weights.h5
# Epoch 31/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 2.0958e-04 - val_loss: 4.1531e-04
#
# Epoch 00031: val_loss improved from 0.00042 to 0.00042, saving model to aug_best_weights.h5
# Epoch 32/150
# 3424/3424 [==============================] - 36s 10ms/step - loss: 2.0161e-04 - val_loss: 4.0159e-04
#
# Epoch 00032: val_loss improved from 0.00042 to 0.00040, saving model to aug_best_weights.h5
# Epoch 33/150
# 3424/3424 [==============================] - 45s 13ms/step - loss: 1.9889e-04 - val_loss: 4.2703e-04
#
# Epoch 00033: val_loss did not improve from 0.00040
# Epoch 34/150
# 3424/3424 [==============================] - 39s 11ms/step - loss: 1.9250e-04 - val_loss: 4.5119e-04
#
# Epoch 00034: val_loss did not improve from 0.00040
# Epoch 35/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 1.9596e-04 - val_loss: 4.2896e-04
#
# Epoch 00035: val_loss did not improve from 0.00040
# Epoch 36/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 1.8707e-04 - val_loss: 4.0658e-04
#
# Epoch 00036: val_loss did not improve from 0.00040
# Epoch 37/150
# 3424/3424 [==============================] - 41s 12ms/step - loss: 1.8529e-04 - val_loss: 4.1959e-04
#
# Epoch 00037: val_loss did not improve from 0.00040
# Epoch 38/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 1.8649e-04 - val_loss: 4.0360e-04
#
# Epoch 00038: val_loss did not improve from 0.00040
# Epoch 39/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 1.7827e-04 - val_loss: 4.2861e-04
#
# Epoch 00039: val_loss did not improve from 0.00040
# Epoch 40/150
# 3424/3424 [==============================] - 42s 12ms/step - loss: 1.8002e-04 - val_loss: 4.0786e-04
#
# Epoch 00040: val_loss did not improve from 0.00040
# Epoch 41/150
# 3424/3424 [==============================] - 42s 12ms/step - loss: 1.7575e-04 - val_loss: 3.9816e-04
#
# Epoch 00041: val_loss improved from 0.00040 to 0.00040, saving model to aug_best_weights.h5
# Epoch 42/150
# 3424/3424 [==============================] - 42s 12ms/step - loss: 1.7061e-04 - val_loss: 4.0180e-04
#
# Epoch 00042: val_loss did not improve from 0.00040
# Epoch 43/150
# 3424/3424 [==============================] - 42s 12ms/step - loss: 1.7250e-04 - val_loss: 4.0375e-04
#
# Epoch 00043: val_loss did not improve from 0.00040
# Epoch 44/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 1.6617e-04 - val_loss: 4.0167e-04
#
# Epoch 00044: val_loss did not improve from 0.00040
# Epoch 45/150
# 3424/3424 [==============================] - 42s 12ms/step - loss: 1.6558e-04 - val_loss: 4.1479e-04
#
# Epoch 00045: val_loss did not improve from 0.00040
# Epoch 46/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 1.6338e-04 - val_loss: 3.9996e-04
#
# Epoch 00046: val_loss did not improve from 0.00040
# Epoch 47/150
# 3424/3424 [==============================] - 47s 14ms/step - loss: 1.6016e-04 - val_loss: 4.0943e-04
#
# Epoch 00047: val_loss did not improve from 0.00040
# Epoch 48/150
# 3424/3424 [==============================] - 45s 13ms/step - loss: 1.5975e-04 - val_loss: 4.0924e-04
#
# Epoch 00048: val_loss did not improve from 0.00040
# Epoch 49/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 1.6207e-04 - val_loss: 4.0384e-04
#
# Epoch 00049: val_loss did not improve from 0.00040
# Epoch 50/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.5662e-04 - val_loss: 4.0374e-04
#
# Epoch 00050: val_loss did not improve from 0.00040
# Epoch 51/150
# 3424/3424 [==============================] - 42s 12ms/step - loss: 1.5471e-04 - val_loss: 3.9539e-04
#
# Epoch 00051: val_loss improved from 0.00040 to 0.00040, saving model to aug_best_weights.h5
# Epoch 52/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 1.5101e-04 - val_loss: 4.0740e-04
#
# Epoch 00052: val_loss did not improve from 0.00040
# Epoch 53/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 1.5153e-04 - val_loss: 3.9132e-04
#
# Epoch 00053: val_loss improved from 0.00040 to 0.00039, saving model to aug_best_weights.h5
# Epoch 54/150
# 3424/3424 [==============================] - 46s 14ms/step - loss: 1.4949e-04 - val_loss: 3.9233e-04
#
# Epoch 00054: val_loss did not improve from 0.00039
# Epoch 55/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.4512e-04 - val_loss: 3.9741e-04
#
# Epoch 00055: val_loss did not improve from 0.00039
# Epoch 56/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 1.4484e-04 - val_loss: 3.9886e-04
#
# Epoch 00056: val_loss did not improve from 0.00039
# Epoch 57/150
# 3424/3424 [==============================] - 42s 12ms/step - loss: 1.4264e-04 - val_loss: 4.1347e-04
#
# Epoch 00057: val_loss did not improve from 0.00039
# Epoch 58/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.4158e-04 - val_loss: 4.0102e-04
#
# Epoch 00058: val_loss did not improve from 0.00039
# Epoch 59/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.4194e-04 - val_loss: 4.1517e-04
#
# Epoch 00059: val_loss did not improve from 0.00039
# Epoch 60/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.3604e-04 - val_loss: 4.0791e-04
#
# Epoch 00060: val_loss did not improve from 0.00039
# Epoch 61/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.3811e-04 - val_loss: 4.0426e-04
#
# Epoch 00061: val_loss did not improve from 0.00039
# Epoch 62/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.3307e-04 - val_loss: 3.8313e-04
#
# Epoch 00062: val_loss improved from 0.00039 to 0.00038, saving model to aug_best_weights.h5
# Epoch 63/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 1.3120e-04 - val_loss: 4.0808e-04
#
# Epoch 00063: val_loss did not improve from 0.00038
# Epoch 64/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.3428e-04 - val_loss: 3.8632e-04
#
# Epoch 00064: val_loss did not improve from 0.00038
# Epoch 65/150
# 3424/3424 [==============================] - 43s 12ms/step - loss: 1.2927e-04 - val_loss: 3.9770e-04
#
# Epoch 00065: val_loss did not improve from 0.00038
# Epoch 66/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.3345e-04 - val_loss: 4.0135e-04
#
# Epoch 00066: val_loss did not improve from 0.00038
# Epoch 67/150
# 3424/3424 [==============================] - 43s 12ms/step - loss: 1.3176e-04 - val_loss: 4.0258e-04
#
# Epoch 00067: val_loss did not improve from 0.00038
# Epoch 68/150
# 3424/3424 [==============================] - 43s 12ms/step - loss: 1.3017e-04 - val_loss: 3.8840e-04
#
# Epoch 00068: val_loss did not improve from 0.00038
# Epoch 69/150
# 3424/3424 [==============================] - 43s 12ms/step - loss: 1.2751e-04 - val_loss: 3.9189e-04
#
# Epoch 00069: val_loss did not improve from 0.00038
# Epoch 70/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 1.2506e-04 - val_loss: 3.9624e-04
#
# Epoch 00070: val_loss did not improve from 0.00038
# Epoch 71/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.2335e-04 - val_loss: 4.0643e-04
#
# Epoch 00071: val_loss did not improve from 0.00038
# Epoch 72/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.2914e-04 - val_loss: 4.0516e-04
#
# Epoch 00072: val_loss did not improve from 0.00038
# Epoch 73/150
# 3424/3424 [==============================] - 43s 12ms/step - loss: 1.2397e-04 - val_loss: 3.9298e-04
#
# Epoch 00073: val_loss did not improve from 0.00038
# Epoch 74/150
# 3424/3424 [==============================] - 43s 12ms/step - loss: 1.1969e-04 - val_loss: 4.0009e-04
#
# Epoch 00074: val_loss did not improve from 0.00038
# Epoch 75/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 1.2027e-04 - val_loss: 3.9434e-04
#
# Epoch 00075: val_loss did not improve from 0.00038
# Epoch 76/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.1789e-04 - val_loss: 3.8990e-04
#
# Epoch 00076: val_loss did not improve from 0.00038
# Epoch 77/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.1709e-04 - val_loss: 4.0388e-04
#
# Epoch 00077: val_loss did not improve from 0.00038
# Epoch 78/150
# 3424/3424 [==============================] - 43s 12ms/step - loss: 1.1984e-04 - val_loss: 4.0086e-04
#
# Epoch 00078: val_loss did not improve from 0.00038
# Epoch 79/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.1710e-04 - val_loss: 4.0425e-04
#
# Epoch 00079: val_loss did not improve from 0.00038
# Epoch 80/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.1532e-04 - val_loss: 3.9163e-04
#
# Epoch 00080: val_loss did not improve from 0.00038
# Epoch 81/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.1448e-04 - val_loss: 3.9637e-04
#
# Epoch 00081: val_loss did not improve from 0.00038
# Epoch 82/150
# 3424/3424 [==============================] - 48s 14ms/step - loss: 1.1446e-04 - val_loss: 3.9612e-04
#
# Epoch 00082: val_loss did not improve from 0.00038
# Epoch 83/150
# 3424/3424 [==============================] - 51s 15ms/step - loss: 1.1331e-04 - val_loss: 3.8974e-04
#
# Epoch 00083: val_loss did not improve from 0.00038
# Epoch 84/150
# 3424/3424 [==============================] - 51s 15ms/step - loss: 1.1196e-04 - val_loss: 4.1463e-04
#
# Epoch 00084: val_loss did not improve from 0.00038
# Epoch 85/150
# 3424/3424 [==============================] - 50s 15ms/step - loss: 1.1231e-04 - val_loss: 3.8774e-04
#
# Epoch 00085: val_loss did not improve from 0.00038
# Epoch 86/150
# 3424/3424 [==============================] - 49s 14ms/step - loss: 1.1053e-04 - val_loss: 3.9653e-04
#
# Epoch 00086: val_loss did not improve from 0.00038
# Epoch 87/150
# 3424/3424 [==============================] - 49s 14ms/step - loss: 1.0925e-04 - val_loss: 3.8486e-04
#
# Epoch 00087: val_loss did not improve from 0.00038
# Epoch 88/150
# 3424/3424 [==============================] - 49s 14ms/step - loss: 1.0721e-04 - val_loss: 4.0504e-04
#
# Epoch 00088: val_loss did not improve from 0.00038
# Epoch 89/150
# 3424/3424 [==============================] - 50s 15ms/step - loss: 1.0995e-04 - val_loss: 4.0491e-04
#
# Epoch 00089: val_loss did not improve from 0.00038
# Epoch 90/150
# 3424/3424 [==============================] - 45s 13ms/step - loss: 1.0909e-04 - val_loss: 3.9779e-04
#
# Epoch 00090: val_loss did not improve from 0.00038
# Epoch 91/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 1.1095e-04 - val_loss: 4.0540e-04
#
# Epoch 00091: val_loss did not improve from 0.00038
# Epoch 92/150
# 3424/3424 [==============================] - 43s 12ms/step - loss: 1.0855e-04 - val_loss: 4.0271e-04
#
# Epoch 00092: val_loss did not improve from 0.00038
# Epoch 93/150
# 3424/3424 [==============================] - 36s 11ms/step - loss: 1.0930e-04 - val_loss: 4.0102e-04
#
# Epoch 00093: val_loss did not improve from 0.00038
# Epoch 94/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 1.0855e-04 - val_loss: 3.9273e-04
#
# Epoch 00094: val_loss did not improve from 0.00038
# Epoch 95/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 1.0502e-04 - val_loss: 3.9064e-04
#
# Epoch 00095: val_loss did not improve from 0.00038
# Epoch 96/150
# 3424/3424 [==============================] - 39s 11ms/step - loss: 1.0527e-04 - val_loss: 4.1015e-04
#
# Epoch 00096: val_loss did not improve from 0.00038
# Epoch 97/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 1.0510e-04 - val_loss: 3.9771e-04
#
# Epoch 00097: val_loss did not improve from 0.00038
# Epoch 98/150
# 3424/3424 [==============================] - 41s 12ms/step - loss: 1.0595e-04 - val_loss: 3.9211e-04
#
# Epoch 00098: val_loss did not improve from 0.00038
# Epoch 99/150
# 3424/3424 [==============================] - 47s 14ms/step - loss: 1.0419e-04 - val_loss: 3.9956e-04
#
# Epoch 00099: val_loss did not improve from 0.00038
# Epoch 100/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 1.0426e-04 - val_loss: 3.8936e-04
#
# Epoch 00100: val_loss did not improve from 0.00038
# Epoch 101/150
# 3424/3424 [==============================] - 42s 12ms/step - loss: 1.0319e-04 - val_loss: 3.9877e-04
#
# Epoch 00101: val_loss did not improve from 0.00038
# Epoch 102/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.0016e-04 - val_loss: 3.8684e-04
#
# Epoch 00102: val_loss did not improve from 0.00038
# Epoch 103/150
# 3424/3424 [==============================] - 43s 12ms/step - loss: 1.0172e-04 - val_loss: 3.9658e-04
#
# Epoch 00103: val_loss did not improve from 0.00038
# Epoch 104/150
# 3424/3424 [==============================] - 46s 13ms/step - loss: 1.0240e-04 - val_loss: 4.0048e-04
#
# Epoch 00104: val_loss did not improve from 0.00038
# Epoch 105/150
# 3424/3424 [==============================] - 45s 13ms/step - loss: 9.9313e-05 - val_loss: 3.8829e-04
#
# Epoch 00105: val_loss did not improve from 0.00038
# Epoch 106/150
# 3424/3424 [==============================] - 43s 13ms/step - loss: 1.0217e-04 - val_loss: 3.8652e-04
#
# Epoch 00106: val_loss did not improve from 0.00038
# Epoch 107/150
# 3424/3424 [==============================] - 46s 13ms/step - loss: 1.0019e-04 - val_loss: 3.9827e-04
#
# Epoch 00107: val_loss did not improve from 0.00038
# Epoch 108/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 9.8277e-05 - val_loss: 3.9826e-04
#
# Epoch 00108: val_loss did not improve from 0.00038
# Epoch 109/150
# 3424/3424 [==============================] - 48s 14ms/step - loss: 9.8369e-05 - val_loss: 3.8464e-04
#
# Epoch 00109: val_loss did not improve from 0.00038
# Epoch 110/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 9.9659e-05 - val_loss: 3.8563e-04
#
# Epoch 00110: val_loss did not improve from 0.00038
# Epoch 111/150
# 3424/3424 [==============================] - 41s 12ms/step - loss: 9.8626e-05 - val_loss: 3.9013e-04
#
# Epoch 00111: val_loss did not improve from 0.00038
# Epoch 112/150
# 3424/3424 [==============================] - 42s 12ms/step - loss: 9.7527e-05 - val_loss: 3.9303e-04
#
# Epoch 00112: val_loss did not improve from 0.00038
# Epoch 113/150
# 3424/3424 [==============================] - 41s 12ms/step - loss: 9.9481e-05 - val_loss: 3.9684e-04
#
# Epoch 00113: val_loss did not improve from 0.00038
# Epoch 114/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 9.8889e-05 - val_loss: 4.1288e-04
#
# Epoch 00114: val_loss did not improve from 0.00038
# Epoch 115/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 9.8529e-05 - val_loss: 4.1525e-04
#
# Epoch 00115: val_loss did not improve from 0.00038
# Epoch 116/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 9.9386e-05 - val_loss: 4.0566e-04
#
# Epoch 00116: val_loss did not improve from 0.00038
# Epoch 117/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 9.5953e-05 - val_loss: 3.9450e-04
#
# Epoch 00117: val_loss did not improve from 0.00038
# Epoch 118/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 9.6940e-05 - val_loss: 4.2777e-04
#
# Epoch 00118: val_loss did not improve from 0.00038
# Epoch 119/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 9.7240e-05 - val_loss: 3.9740e-04
#
# Epoch 00119: val_loss did not improve from 0.00038
# Epoch 120/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 9.4677e-05 - val_loss: 3.8796e-04
#
# Epoch 00120: val_loss did not improve from 0.00038
# Epoch 121/150
# 3424/3424 [==============================] - 39s 12ms/step - loss: 9.4159e-05 - val_loss: 3.9094e-04
#
# Epoch 00121: val_loss did not improve from 0.00038
# Epoch 122/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 9.4356e-05 - val_loss: 3.9303e-04
#
# Epoch 00122: val_loss did not improve from 0.00038
# Epoch 123/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 9.3166e-05 - val_loss: 4.0617e-04
#
# Epoch 00123: val_loss did not improve from 0.00038
# Epoch 124/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 9.2922e-05 - val_loss: 3.9265e-04
#
# Epoch 00124: val_loss did not improve from 0.00038
# Epoch 125/150
# 3424/3424 [==============================] - 39s 11ms/step - loss: 9.4720e-05 - val_loss: 4.1109e-04
#
# Epoch 00125: val_loss did not improve from 0.00038
# Epoch 126/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 9.4312e-05 - val_loss: 4.0849e-04
#
# Epoch 00126: val_loss did not improve from 0.00038
# Epoch 127/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 9.1759e-05 - val_loss: 4.0193e-04
#
# Epoch 00127: val_loss did not improve from 0.00038
# Epoch 128/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 9.3300e-05 - val_loss: 3.9924e-04
#
# Epoch 00128: val_loss did not improve from 0.00038
# Epoch 129/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 9.1594e-05 - val_loss: 3.9434e-04
#
# Epoch 00129: val_loss did not improve from 0.00038
# Epoch 130/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 9.4302e-05 - val_loss: 3.9805e-04
#
# Epoch 00130: val_loss did not improve from 0.00038
# Epoch 131/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 9.3888e-05 - val_loss: 4.0692e-04
#
# Epoch 00131: val_loss did not improve from 0.00038
# Epoch 132/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 9.1748e-05 - val_loss: 4.0830e-04
#
# Epoch 00132: val_loss did not improve from 0.00038
# Epoch 133/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 9.0708e-05 - val_loss: 3.9578e-04
#
# Epoch 00133: val_loss did not improve from 0.00038
# Epoch 134/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 9.1497e-05 - val_loss: 4.0657e-04
#
# Epoch 00134: val_loss did not improve from 0.00038
# Epoch 135/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 9.0716e-05 - val_loss: 4.0066e-04
#
# Epoch 00135: val_loss did not improve from 0.00038
# Epoch 136/150
# 3424/3424 [==============================] - 39s 12ms/step - loss: 8.9887e-05 - val_loss: 4.0131e-04
#
# Epoch 00136: val_loss did not improve from 0.00038
# Epoch 137/150
# 3424/3424 [==============================] - 40s 12ms/step - loss: 8.9135e-05 - val_loss: 4.1170e-04
#
# Epoch 00137: val_loss did not improve from 0.00038
# Epoch 138/150
# 3424/3424 [==============================] - 44s 13ms/step - loss: 9.0056e-05 - val_loss: 4.0543e-04
#
# Epoch 00138: val_loss did not improve from 0.00038
# Epoch 139/150
# 3424/3424 [==============================] - 37s 11ms/step - loss: 9.2669e-05 - val_loss: 4.0164e-04
#
# Epoch 00139: val_loss did not improve from 0.00038
# Epoch 140/150
# 3424/3424 [==============================] - 39s 11ms/step - loss: 8.8616e-05 - val_loss: 4.1983e-04
#
# Epoch 00140: val_loss did not improve from 0.00038
# Epoch 141/150
# 3424/3424 [==============================] - 37s 11ms/step - loss: 8.7713e-05 - val_loss: 4.0563e-04
#
# Epoch 00141: val_loss did not improve from 0.00038
# Epoch 142/150
# 3424/3424 [==============================] - 37s 11ms/step - loss: 8.9384e-05 - val_loss: 3.9575e-04
#
# Epoch 00142: val_loss did not improve from 0.00038
# Epoch 143/150
# 3424/3424 [==============================] - 39s 11ms/step - loss: 8.9888e-05 - val_loss: 4.2234e-04
#
# Epoch 00143: val_loss did not improve from 0.00038
# Epoch 144/150
# 3424/3424 [==============================] - 37s 11ms/step - loss: 8.9867e-05 - val_loss: 4.0194e-04
#
# Epoch 00144: val_loss did not improve from 0.00038
# Epoch 145/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 8.8526e-05 - val_loss: 4.0949e-04
#
# Epoch 00145: val_loss did not improve from 0.00038
# Epoch 146/150
# 3424/3424 [==============================] - 39s 11ms/step - loss: 8.8366e-05 - val_loss: 4.0783e-04
#
# Epoch 00146: val_loss did not improve from 0.00038
# Epoch 147/150
# 3424/3424 [==============================] - 37s 11ms/step - loss: 8.9493e-05 - val_loss: 4.0083e-04
#
# Epoch 00147: val_loss did not improve from 0.00038
# Epoch 148/150
# 3424/3424 [==============================] - 39s 11ms/step - loss: 8.9916e-05 - val_loss: 3.9946e-04
#
# Epoch 00148: val_loss did not improve from 0.00038
# Epoch 149/150
# 3424/3424 [==============================] - 37s 11ms/step - loss: 8.9213e-05 - val_loss: 4.0410e-04
#
# Epoch 00149: val_loss did not improve from 0.00038
# Epoch 150/150
# 3424/3424 [==============================] - 38s 11ms/step - loss: 8.6760e-05 - val_loss: 4.0171e-04
#
# Epoch 00150: val_loss did not improve from 0.00038

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(aug_hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(aug_hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
aug_points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(aug_points_test[i]))
